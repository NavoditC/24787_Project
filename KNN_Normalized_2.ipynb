# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import warnings
from sklearn.preprocessing import StandardScaler

warnings.filterwarnings("ignore")

# Reading the dataset
dataset = pd.read_csv("wdbc.data", sep=",").values

#Normalizing all Data by feature
normDataset = np.empty(dataset.shape)
normDataset[:,0:1] = dataset[:,0:1]
print(np.mean(dataset[:,2:2+1]))

print(np.std(dataset[:,2:2+1]))
for i in range(29):
    index = i+2
    normDataset[:,index:index+1] = np.divide(dataset[:,index:index+1]-np.mean(dataset[:,index:index+1]),np.std(dataset[:,index:index+1]))

# Forming a data frame 
attributes = ["ID","Diagnosis","mean_radius","mean_texture","mean_perimeter","mean_area","mean_smoothness","mean_compactness","mean_concavity","mean_concave_points","mean_symmetry","mean_fractal_dimension","se_radius","se_texture","se_perimeter","se_area","se_smoothness","se_compactness","se_concavity","se_concave_points","se_symmetry","se_fractal_dimension",
            "worst_radius","worst_texture","worst_perimeter","worst_area","worst_smoothness","worst_compactness","worst_concavity","worst_concave_points","worst_symmetry","worst_fractal_dimension"]
data = pd.DataFrame(data=dataset,columns=attributes)
data.set_index("ID", inplace=True)

# Forming a data frame with the normalized data
normData = pd.DataFrame(data=normDataset,columns=attributes)
normData.set_index("ID", inplace=True)



# Displaying the diagnosis(M = malignant, B = benign) and the 30 real-valued attributes
display(data.head())
display(normData.head())
# Out:
# 14.12049119718311
# 3.520313248794888
#          Diagnosis mean_radius mean_texture mean_perimeter mean_area  \
# ID
# 842517           M       20.57        17.77          132.9    1326.0
# 84300903         M       19.69        21.25          130.0    1203.0
# 84348301         M       11.42        20.38          77.58     386.1
# 84358402         M       20.29        14.34          135.1    1297.0
# 843786           M       12.45         15.7          82.57     477.1
#
#          mean_smoothness mean_compactness mean_concavity mean_concave_points  \
# ID
# 842517           0.08474          0.07864         0.0869             0.07017
# 84300903          0.1096           0.1599         0.1974              0.1279
# 84348301          0.1425           0.2839         0.2414              0.1052
# 84358402          0.1003           0.1328          0.198              0.1043
# 843786            0.1278             0.17         0.1578             0.08089
#
#          mean_symmetry  ... worst_radius worst_texture worst_perimeter  \
# ID                      ...
# 842517          0.1812  ...        24.99         23.41           158.8
# 84300903        0.2069  ...        23.57         25.53           152.5
# 84348301        0.2597  ...        14.91          26.5           98.87
# 84358402        0.1809  ...        22.54         16.67           152.2
# 843786          0.2087  ...        15.47         23.75           103.4
#
#          worst_area worst_smoothness worst_compactness worst_concavity  \
# ID
# 842517       1956.0           0.1238            0.1866          0.2416
# 84300903     1709.0           0.1444            0.4245          0.4504
# 84348301      567.7           0.2098            0.8663          0.6869
# 84358402     1575.0           0.1374             0.205             0.4
# 843786        741.6           0.1791            0.5249          0.5355
#
#          worst_concave_points worst_symmetry worst_fractal_dimension
# ID
# 842517                  0.186          0.275                 0.08902
# 84300903                0.243         0.3613                 0.08758
# 84348301               0.2575         0.6638                   0.173
# 84358402               0.1625         0.2364                 0.07678
# 843786                 0.1741         0.3985                  0.1244
#
# [5 rows x 31 columns]
#                 Diagnosis  mean_radius  mean_texture  mean_perimeter  \
# ID
# 842517.0    1.245964e-311     1.832084     -0.358327        1.689106
# 84300903.0  1.245995e-311     1.582106      0.453860        1.569590
# 84348301.0  1.245995e-311    -0.767117      0.250813       -0.590772
# 84358402.0  1.245995e-311     1.752545     -1.158844        1.779774
# 843786.0    1.245995e-311    -0.474529     -0.841438       -0.385121
#
#             mean_area  mean_smoothness  mean_compactness  mean_concavity  \
# ID
# 842517.0     1.910392        -0.825266         -0.485498       -0.019278
# 84300903.0   1.560576         0.946192          1.067960        1.375494
# 84348301.0  -0.762711         3.290559          3.438483        1.930879
# 84358402.0   1.827915         0.283499          0.549886        1.383068
# 843786.0    -0.503904         2.243076          1.261043        0.875648
#
#             mean_concave_points  mean_symmetry  ...  worst_radius  \
# ID                                              ...
# 842517.0               0.555261       0.005315  ...      1.813349
# 84300903.0             2.051509       0.946867  ...      1.518626
# 84348301.0             1.463170       2.881262  ...     -0.278773
# 84358402.0             1.439844      -0.005676  ...      1.304847
# 843786.0               0.833102       1.012812  ...     -0.162544
#
#             worst_texture  worst_perimeter  worst_area  worst_smoothness  \
# ID
# 842517.0        -0.371875         1.545063    1.899054         -0.373544
# 84300903.0      -0.026387         1.356695    1.463694          0.530042
# 84348301.0       0.131690        -0.246823   -0.547953          3.398711
# 84358402.0      -1.470265         1.347725    1.227507          0.222998
# 843786.0        -0.316467        -0.111378   -0.241438          2.052104
#
#             worst_compactness  worst_concavity  worst_concave_points  \
# ID
# 842517.0            -0.428051        -0.143472              1.095262
# 84300903.0           1.093192         0.861314              1.966468
# 84348301.0           3.918265         1.999398              2.188090
# 84358402.0          -0.310393         0.618779              0.736081
# 843786.0             1.735196         1.270831              0.913379
#
#             worst_symmetry  worst_fractal_dimension
# ID
# 842517.0         -0.240444            1.245995e-311
# 84300903.0        1.163858            1.245995e-311
# 84348301.0        6.086236            1.245995e-311
# 84358402.0       -0.868555            1.245995e-311
# 843786.0          1.769188            1.245995e-311
#
# [5 rows x 31 columns]

# %%
# Label-1 indicates malignant and Label-0 indicates benign 
data["Diagnosis"] = data["Diagnosis"].replace("M",1)
data["Diagnosis"] = data["Diagnosis"].replace("B",0)
data = data.apply(pd.to_numeric, errors="ignore")

#overwrite with normalized data
replace_label_array = ["mean_radius","mean_texture","mean_perimeter","mean_area","mean_smoothness","mean_compactness","mean_concavity","mean_concave_points","mean_symmetry","mean_fractal_dimension","se_radius","se_texture","se_perimeter","se_area","se_smoothness","se_compactness","se_concavity","se_concave_points","se_symmetry","se_fractal_dimension",
            "worst_radius","worst_texture","worst_perimeter","worst_area","worst_smoothness","worst_compactness","worst_concavity","worst_concave_points","worst_symmetry","worst_fractal_dimension"]
data[replace_label_array] = normData[replace_label_array]  #<<<< comment out to use non-normalized data
#display(data.head())
dataset[:,2:]=normDataset[:,2:]


# X contains only the first 10 features i.e only the mean values of the attributes not their standard error or maximum values

# Mean
X1 = dataset[:,2:12]
X1 = X1.astype("float64")
X1 = np.concatenate([np.ones((X1.shape[0],1)),X1],axis=1)

# Standard error
X2 = dataset[:,12:22]
X2 = X2.astype("float64")
X2 = np.concatenate([np.ones((X2.shape[0],1)),X2],axis=1)

# Maximum
X3 = dataset[:,22:32]
X3 = X3.astype("float64")
X3 = np.concatenate([np.ones((X3.shape[0],1)),X3],axis=1)

# Mean and Standard error
X4 = dataset[:,2:22]
X4 = X4.astype("float64")
X4 = np.concatenate([np.ones((X4.shape[0],1)),X4],axis=1)

# Standard error and Maximum
X5 = dataset[:,12:]
X5 = X5.astype("float64")
X5 = np.concatenate([np.ones((X5.shape[0],1)),X5],axis=1)

# Mean and Maximum
X6 = np.concatenate([X1,X3],axis=1)
X6 = X6.astype("float64")
X6 = np.concatenate([np.ones((X6.shape[0],1)),X6],axis=1)

# Mean, Standard error and Maximum
X7 = dataset[:,2:]
X7 = X7.astype("float64")
X7 = np.concatenate([np.ones((X7.shape[0],1)),X7],axis=1)


labels = data["Diagnosis"].values.reshape(-1,1)
data.drop("Diagnosis", axis = 1, inplace = True)
final_data1 = np.concatenate([X1,labels],axis=1)
final_data2 = np.concatenate([X2,labels],axis=1)
final_data3 = np.concatenate([X3,labels],axis=1)
final_data4 = np.concatenate([X4,labels],axis=1)
final_data5 = np.concatenate([X5,labels],axis=1)
final_data6 = np.concatenate([X6,labels],axis=1)
final_data7 = np.concatenate([X7,labels],axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import classification_report
np.random.seed(0)


def evaluate(final_data):
    report = np.empty([5, 6]) #row, column
    m,n = final_data.shape
    for i in range(5):
        
        np.random.shuffle(final_data)
        x_train = final_data[0:int(0.8*m),0:n-1]
        y_train = final_data[0:int(0.8*m),n-1]
        x_test  = final_data[int(0.8*m):,0:n-1]
        y_test  = final_data[int(0.8*m):,n-1]
        
        optimal_nearest_neighbors = -1
        maxAccuracy = 0.0
        for neighbors in range(1,100):
            knn = KNeighborsClassifier(n_neighbors = neighbors)
            knn.fit(x_train,y_train)
            predictions = knn.predict(x_test)        
            accuracy = (sum([1 if y_test[i]==predictions[i] else 0 for i in range(y_test.shape[0])])/y_test.shape[0])*100
            if round(accuracy, 5)>round(maxAccuracy, 5):
                maxAccuracy = accuracy
                optimal_nearest_neighbors=neighbors            
        knn = KNeighborsClassifier(n_neighbors = optimal_nearest_neighbors)
        knn.fit(x_train,y_train)
        predictions = knn.predict(x_test)                
        print("\nAccuracy using sklearn: {:.2f}%\n".format(accuracy))
        print("The optimal number of nearest neighbors was "+str(optimal_nearest_neighbors ))
        
        report[0,i] = (classification_report(y_test,predictions, output_dict=True).get('accuracy'))
        report[1,i] = (classification_report(y_test,predictions, output_dict=True).get('macro avg').get('precision'))
        report[2,i] =(classification_report(y_test,predictions, output_dict=True).get('macro avg').get('recall'))
        report[3,i] =(classification_report(y_test,predictions, output_dict=True).get('macro avg').get('f1-score'))
        report[4,i] = optimal_nearest_neighbors
        print(classification_report(y_test,predictions))

        cm = metrics.confusion_matrix(y_test, predictions)
        print("Confusion matrix:\n",cm)
    
    #reporting the maximum values for each row
    for i in range(5):
        report[i,5]= max(report[i,0:5])
    
    
    columns = ["Validation1","Validation2","Validation3","Validation4","Validation5","Maximum Value"]
    index = ["Accuracy", "Precision", "Recall", "F1 Score", "Optimal Neighbors"]
    df1 = pd.DataFrame(data = report, columns = columns, index = index)
    display(df1)

# %% [markdown]
# # Mean

# %%
# Mean
evaluate(final_data1)
# Out:
# Accuracy using sklearn: 90.35%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.97      0.96        75
#          1.0       0.95      0.90      0.92        39
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# Confusion matrix:
#  [[73  2]
#  [ 4 35]]
#
# Accuracy using sklearn: 90.35%
#
# The optimal number of nearest neighbors was 19
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.97        71
#          1.0       1.00      0.88      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.94      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Confusion matrix:
#  [[71  0]
#  [ 5 38]]
#
# Accuracy using sklearn: 92.11%
#
# The optimal number of nearest neighbors was 2
#               precision    recall  f1-score   support
#
#          0.0       0.90      1.00      0.95        74
#          1.0       1.00      0.80      0.89        40
#
#     accuracy                           0.93       114
#    macro avg       0.95      0.90      0.92       114
# weighted avg       0.94      0.93      0.93       114
#
# Confusion matrix:
#  [[74  0]
#  [ 8 32]]
#
# Accuracy using sklearn: 93.86%
#
# The optimal number of nearest neighbors was 4
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.99      0.96        78
#          1.0       0.97      0.86      0.91        36
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.92      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# Confusion matrix:
#  [[77  1]
#  [ 5 31]]
#
# Accuracy using sklearn: 92.98%
#
# The optimal number of nearest neighbors was 4
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.97      0.98        73
#          1.0       0.95      0.98      0.96        41
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion matrix:
#  [[71  2]
#  [ 1 40]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.947368     0.956140     0.929825     0.947368
# Precision             0.946999     0.967105     0.951220     0.953887
# Recall                0.935385     0.941860     0.900000     0.924145
# F1 Score              0.940789     0.952129     0.918803     0.937132
# Optimal Neighbors     3.000000    19.000000     2.000000     4.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.973684       0.973684
# Precision             0.969246       0.969246
# Recall                0.974106       0.974106
# F1 Score              0.971583       0.971583
# Optimal Neighbors     4.000000      19.000000

# %% [markdown]
# # Standard Error

# %%
# Standard Error
evaluate(final_data2)
# Out:
# Accuracy using sklearn: 77.19%
#
# The optimal number of nearest neighbors was 24
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.93      0.88        70
#          1.0       0.86      0.70      0.78        44
#
#     accuracy                           0.84       114
#    macro avg       0.85      0.82      0.83       114
# weighted avg       0.84      0.84      0.84       114
#
# Confusion matrix:
#  [[65  5]
#  [13 31]]
#
# Accuracy using sklearn: 82.46%
#
# The optimal number of nearest neighbors was 60
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.99      0.90        71
#          1.0       0.97      0.67      0.79        43
#
#     accuracy                           0.87       114
#    macro avg       0.90      0.83      0.85       114
# weighted avg       0.88      0.87      0.86       114
#
# Confusion matrix:
#  [[70  1]
#  [14 29]]
#
# Accuracy using sklearn: 78.95%
#
# The optimal number of nearest neighbors was 35
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.93      0.88        72
#          1.0       0.85      0.67      0.75        42
#
#     accuracy                           0.83       114
#    macro avg       0.84      0.80      0.81       114
# weighted avg       0.84      0.83      0.83       114
#
# Confusion matrix:
#  [[67  5]
#  [14 28]]
#
# Accuracy using sklearn: 87.72%
#
# The optimal number of nearest neighbors was 30
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.92      0.90        65
#          1.0       0.89      0.82      0.85        49
#
#     accuracy                           0.88       114
#    macro avg       0.88      0.87      0.87       114
# weighted avg       0.88      0.88      0.88       114
#
# Confusion matrix:
#  [[60  5]
#  [ 9 40]]
#
# Accuracy using sklearn: 80.70%
#
# The optimal number of nearest neighbors was 21
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.93      0.94        74
#          1.0       0.88      0.90      0.89        40
#
#     accuracy                           0.92       114
#    macro avg       0.91      0.92      0.91       114
# weighted avg       0.92      0.92      0.92       114
#
# Confusion matrix:
#  [[69  5]
#  [ 4 36]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.842105     0.868421     0.833333     0.877193
# Precision             0.847222     0.900000     0.837823     0.879227
# Recall                0.816558     0.830167     0.798611     0.869702
# F1 Score              0.826689     0.848873     0.811242     0.873293
# Optimal Neighbors    24.000000    60.000000    35.000000    30.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.921053       0.921053
# Precision             0.911627       0.911627
# Recall                0.916216       0.916216
# F1 Score              0.913832       0.913832
# Optimal Neighbors    21.000000      60.000000

# %% [markdown]
# # Maximum

# %%
# Maximum
evaluate(final_data3)
# Out:
# Accuracy using sklearn: 96.49%
#
# The optimal number of nearest neighbors was 6
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        69
#          1.0       1.00      1.00      1.00        45
#
#     accuracy                           1.00       114
#    macro avg       1.00      1.00      1.00       114
# weighted avg       1.00      1.00      1.00       114
#
# Confusion matrix:
#  [[69  0]
#  [ 0 45]]
#
# Accuracy using sklearn: 92.11%
#
# The optimal number of nearest neighbors was 1
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97        77
#          1.0       0.97      0.92      0.94        37
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.95      0.96       114
# weighted avg       0.97      0.96      0.96       114
#
# Confusion matrix:
#  [[76  1]
#  [ 3 34]]
#
# Accuracy using sklearn: 97.37%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99        73
#          1.0       0.98      0.98      0.98        41
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[72  1]
#  [ 1 40]]
#
# Accuracy using sklearn: 93.86%
#
# The optimal number of nearest neighbors was 8
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98        65
#          1.0       1.00      0.94      0.97        49
#
#     accuracy                           0.97       114
#    macro avg       0.98      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion matrix:
#  [[65  0]
#  [ 3 46]]
#
# Accuracy using sklearn: 91.23%
#
# The optimal number of nearest neighbors was 9
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.97        57
#          1.0       1.00      0.93      0.96        57
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114
#
# Confusion matrix:
#  [[57  0]
#  [ 4 53]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy                   1.0     0.964912     0.982456     0.973684
# Precision                  1.0     0.966727     0.980956     0.977941
# Recall                     1.0     0.952966     0.980956     0.969388
# F1 Score                   1.0     0.959402     0.980956     0.972932
# Optimal Neighbors          6.0     1.000000     3.000000     8.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.964912            1.0
# Precision             0.967213            1.0
# Recall                0.964912            1.0
# F1 Score              0.964869            1.0
# Optimal Neighbors     9.000000            9.0

# %% [markdown]
# # Mean and Standard Error

# %%
# Mean and Standard Error
evaluate(final_data4)
# Out:
# Accuracy using sklearn: 89.47%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.99        75
#          1.0       1.00      0.95      0.97        39
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.97      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[75  0]
#  [ 2 37]]
#
# Accuracy using sklearn: 95.61%
#
# The optimal number of nearest neighbors was 6
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99        82
#          1.0       1.00      0.94      0.97        32
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.97      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[82  0]
#  [ 2 30]]
#
# Accuracy using sklearn: 92.98%
#
# The optimal number of nearest neighbors was 17
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98        74
#          1.0       0.97      0.95      0.96        40
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion matrix:
#  [[73  1]
#  [ 2 38]]
#
# Accuracy using sklearn: 91.23%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.98      0.96        61
#          1.0       0.98      0.92      0.95        53
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.96       114
# weighted avg       0.96      0.96      0.96       114
#
# Confusion matrix:
#  [[60  1]
#  [ 4 49]]
#
# Accuracy using sklearn: 84.21%
#
# The optimal number of nearest neighbors was 1
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.99      0.95        70
#          1.0       0.97      0.86      0.92        44
#
#     accuracy                           0.94       114
#    macro avg       0.95      0.92      0.93       114
# weighted avg       0.94      0.94      0.94       114
#
# Confusion matrix:
#  [[69  1]
#  [ 6 38]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.982456     0.982456     0.973684     0.956140
# Precision             0.987013     0.988095     0.973846     0.958750
# Recall                0.974359     0.968750     0.968243     0.954067
# F1 Score              0.980263     0.977847     0.970946     0.955728
# Optimal Neighbors     3.000000     6.000000    17.000000     3.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.938596       0.982456
# Precision             0.947179       0.988095
# Recall                0.924675       0.974359
# F1 Score              0.933693       0.980263
# Optimal Neighbors     1.000000      17.000000

# %% [markdown]
# # Standard Error and Maximum

# %%
# Standard Error and Maximum
evaluate(final_data5)
# Out:
# Accuracy using sklearn: 93.86%
#
# The optimal number of nearest neighbors was 5
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98        68
#          1.0       1.00      0.93      0.97        46
#
#     accuracy                           0.97       114
#    macro avg       0.98      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion matrix:
#  [[68  0]
#  [ 3 43]]
#
# Accuracy using sklearn: 92.98%
#
# The optimal number of nearest neighbors was 4
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.97        71
#          1.0       1.00      0.88      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.94      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Confusion matrix:
#  [[71  0]
#  [ 5 38]]
#
# Accuracy using sklearn: 89.47%
#
# The optimal number of nearest neighbors was 1
#               precision    recall  f1-score   support
#
#          0.0       0.90      1.00      0.95        71
#          1.0       1.00      0.81      0.90        43
#
#     accuracy                           0.93       114
#    macro avg       0.95      0.91      0.92       114
# weighted avg       0.94      0.93      0.93       114
#
# Confusion matrix:
#  [[71  0]
#  [ 8 35]]
#
# Accuracy using sklearn: 88.60%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.88      1.00      0.94        61
#          1.0       1.00      0.85      0.92        53
#
#     accuracy                           0.93       114
#    macro avg       0.94      0.92      0.93       114
# weighted avg       0.94      0.93      0.93       114
#
# Confusion matrix:
#  [[61  0]
#  [ 8 45]]
#
# Accuracy using sklearn: 88.60%
#
# The optimal number of nearest neighbors was 8
#               precision    recall  f1-score   support
#
#          0.0       0.90      1.00      0.95        57
#          1.0       1.00      0.89      0.94        57
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.95      0.95       114
# weighted avg       0.95      0.95      0.95       114
#
# Confusion matrix:
#  [[57  0]
#  [ 6 51]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.973684     0.956140     0.929825     0.929825
# Precision             0.978873     0.967105     0.949367     0.942029
# Recall                0.967391     0.941860     0.906977     0.924528
# F1 Score              0.972355     0.952129     0.922051     0.928414
# Optimal Neighbors     5.000000     4.000000     1.000000     3.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.947368       0.973684
# Precision             0.952381       0.978873
# Recall                0.947368       0.967391
# F1 Score              0.947222       0.972355
# Optimal Neighbors     8.000000       8.000000

# %%
# Mean and Maximum

# %%
# Mean and Maximum
evaluate(final_data6)
# Out:
# Accuracy using sklearn: 94.74%
#
# The optimal number of nearest neighbors was 7
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99        65
#          1.0       1.00      0.98      0.99        49
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# Confusion matrix:
#  [[65  0]
#  [ 1 48]]
#
# Accuracy using sklearn: 96.49%
#
# The optimal number of nearest neighbors was 2
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97        77
#          1.0       1.00      0.89      0.94        37
#
#     accuracy                           0.96       114
#    macro avg       0.98      0.95      0.96       114
# weighted avg       0.97      0.96      0.96       114
#
# Confusion matrix:
#  [[77  0]
#  [ 4 33]]
#
# Accuracy using sklearn: 90.35%
#
# The optimal number of nearest neighbors was 8
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96        68
#          1.0       1.00      0.87      0.93        46
#
#     accuracy                           0.95       114
#    macro avg       0.96      0.93      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# Confusion matrix:
#  [[68  0]
#  [ 6 40]]
#
# Accuracy using sklearn: 96.49%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        71
#          1.0       1.00      0.98      0.99        43
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# Confusion matrix:
#  [[71  0]
#  [ 1 42]]
#
# Accuracy using sklearn: 93.86%
#
# The optimal number of nearest neighbors was 2
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97        65
#          1.0       1.00      0.92      0.96        49
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114
#
# Confusion matrix:
#  [[65  0]
#  [ 4 45]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.991228     0.964912     0.947368     0.991228
# Precision             0.992424     0.975309     0.959459     0.993056
# Recall                0.989796     0.945946     0.934783     0.988372
# F1 Score              0.991029     0.958770     0.943990     0.990621
# Optimal Neighbors     7.000000     2.000000     8.000000     3.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.964912       0.991228
# Precision             0.971014       0.993056
# Recall                0.959184       0.989796
# F1 Score              0.963798       0.991029
# Optimal Neighbors     2.000000       8.000000

# %% [markdown]
# # Mean, Standard Error and Maximum

# %%
# Mean, Standard Error and Maximum
evaluate(final_data7)
# Out:
# Accuracy using sklearn: 90.35%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97        75
#          1.0       0.97      0.90      0.93        39
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.94      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Confusion matrix:
#  [[74  1]
#  [ 4 35]]
#
# Accuracy using sklearn: 93.86%
#
# The optimal number of nearest neighbors was 2
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.99        76
#          1.0       1.00      0.95      0.97        38
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.97      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[76  0]
#  [ 2 36]]
#
# Accuracy using sklearn: 95.61%
#
# The optimal number of nearest neighbors was 9
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99        70
#          1.0       0.98      0.98      0.98        44
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[69  1]
#  [ 1 43]]
#
# Accuracy using sklearn: 94.74%
#
# The optimal number of nearest neighbors was 1
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99        69
#          1.0       0.98      0.98      0.98        45
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[68  1]
#  [ 1 44]]
#
# Accuracy using sklearn: 89.47%
#
# The optimal number of nearest neighbors was 2
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        63
#          1.0       1.00      0.94      0.97        51
#
#     accuracy                           0.97       114
#    macro avg       0.98      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion matrix:
#  [[63  0]
#  [ 3 48]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.956140     0.982456     0.982456     0.982456
# Precision             0.960470     0.987179     0.981494     0.981643
# Recall                0.942051     0.973684     0.981494     0.981643
# F1 Score              0.950327     0.979993     0.981494     0.981643
# Optimal Neighbors     3.000000     2.000000     9.000000     1.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.973684       0.982456
# Precision             0.977273       0.987179
# Recall                0.970588       0.981643
# F1 Score              0.973221       0.981643
# Optimal Neighbors     2.000000       9.000000

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_axes([0,0,1,1])
plt.rcParams["font.family"] = "Times New Roman"

feature_comb = ['Mean', 'SE', 'Max', 'Mean\n& SE', 'Max\n& SE', 'Mean\n& Max', 'Mean, Max\n & SE']

accuracy = [0.973684,0.921053,0.982456,0.982456,0.956140,0.982456,0.973684]
ax.bar(feature_comb,accuracy)
ax.set_xlabel('Feature Combinations', fontsize = 20)
ax.set_ylabel('Accuracy', fontsize = 20)
ax.set_title('Comparison of Accuracy Using Different Feature \nCombinations using K-NN (With Normalization)', fontsize = 22)

for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

plt.ylim([0.875, 1])
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_axes([0,0,1,1])
plt.rcParams["font.family"] = "Times New Roman"

feature_comb = ['Mean', 'SE', 'Max', 'Mean\n& SE', 'Max\n& SE', 'Mean\n& Max', 'Mean, Max\n & SE']

accuracy = [0.962660, 0.855696, 0.990856, 0.972120, 0.980263, 0.990195, 0.990195]
ax.bar(feature_comb,accuracy)
ax.set_xlabel('Feature Combinations', fontsize = 20)
ax.set_ylabel('F1', fontsize = 20)
ax.set_title('Comparison of F1 Score Using Different Feature \nCombinations using K-NN (With Normalization)', fontsize = 22)

for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

plt.ylim([0.875, 1])
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics



np.random.seed(0)

def evaluate(final_data):
    report = np.empty([5, 6]) #row, column
    m,n = final_data.shape
    for i in range(5):
        
        np.random.shuffle(final_data)
        x_train = final_data[0:int(0.8*m),0:n-1]
        y_train = final_data[0:int(0.8*m),n-1]
        x_test  = final_data[int(0.8*m):,0:n-1]
        y_test  = final_data[int(0.8*m):,n-1]
        
        optimal_nearest_neighbors = -1
        maxAccuracy = 0.0
        for neighbors in range(1,100):
            knn = KNeighborsClassifier(n_neighbors = neighbors)
            knn.fit(x_train,y_train)
            predictions = knn.predict(x_test)        
            accuracy = (sum([1 if y_test[i]==predictions[i] else 0 for i in range(y_test.shape[0])])/y_test.shape[0])*100
            if round(accuracy, 5)>round(maxAccuracy, 5):
                maxAccuracy = accuracy
                optimal_nearest_neighbors=neighbors            
        knn = KNeighborsClassifier(n_neighbors = optimal_nearest_neighbors)
        knn.fit(x_train,y_train)
        predictions = knn.predict(x_test)                
        print("\nAccuracy using sklearn: {:.2f}%\n".format(accuracy))
        print("The optimal number of nearest neighbors was "+str(optimal_nearest_neighbors ))
        report[0,i] = (classification_report(y_test,predictions, output_dict=True).get('accuracy'))
        report[1,i] = (classification_report(y_test,predictions, output_dict=True).get('macro avg').get('precision'))
        report[2,i] =(classification_report(y_test,predictions, output_dict=True).get('macro avg').get('recall'))
        report[3,i] =(classification_report(y_test,predictions, output_dict=True).get('macro avg').get('f1-score'))
        report[4,i] = optimal_nearest_neighbors
        print(classification_report(y_test,predictions))

        cm = metrics.confusion_matrix(y_test, predictions)
        print("Confusion matrix:\n",cm)
    
    #reporting the maximum values for each row
    for i in range(5):
        report[i,5]= max(report[i,0:5])
    
    
    columns = ["Validation1","Validation2","Validation3","Validation4","Validation5","Maximum Value"]
    index = ["Accuracy", "Precision", "Recall", "F1 Score", "Optimal Neighbors"]
    df1 = pd.DataFrame(data = report, columns = columns, index = index)
    display(df1)

# %%
# Mean
evaluate(final_data1)
# Out:
# Accuracy using sklearn: 89.47%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.96      0.94        72
#          1.0       0.92      0.86      0.89        42
#
#     accuracy                           0.92       114
#    macro avg       0.92      0.91      0.91       114
# weighted avg       0.92      0.92      0.92       114
#
# Confusion matrix:
#  [[69  3]
#  [ 6 36]]
#
# Accuracy using sklearn: 93.86%
#
# The optimal number of nearest neighbors was 12
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98        64
#          1.0       0.98      0.98      0.98        50
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[63  1]
#  [ 1 49]]
#
# Accuracy using sklearn: 94.74%
#
# The optimal number of nearest neighbors was 8
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        79
#          1.0       1.00      0.97      0.99        35
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# Confusion matrix:
#  [[79  0]
#  [ 1 34]]
#
# Accuracy using sklearn: 92.98%
#
# The optimal number of nearest neighbors was 21
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98        72
#          1.0       0.98      0.95      0.96        42
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion matrix:
#  [[71  1]
#  [ 2 40]]
#
# Accuracy using sklearn: 93.86%
#
# The optimal number of nearest neighbors was 8
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98        72
#          1.0       0.98      0.95      0.96        42
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion matrix:
#  [[71  1]
#  [ 2 40]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.921053     0.982456     0.991228     0.973684
# Precision             0.921538     0.982187     0.993750     0.974106
# Recall                0.907738     0.982187     0.985714     0.969246
# F1 Score              0.913832     0.982187     0.989609     0.971583
# Optimal Neighbors     3.000000    12.000000     8.000000    21.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.973684       0.991228
# Precision             0.974106       0.993750
# Recall                0.969246       0.985714
# F1 Score              0.971583       0.989609
# Optimal Neighbors     8.000000      21.000000

# %% [markdown]
# # Standard Error

# %%
# Standard Error
evaluate(final_data2)
# Out:
# Accuracy using sklearn: 78.95%
#
# The optimal number of nearest neighbors was 30
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.93      0.87        71
#          1.0       0.85      0.67      0.75        43
#
#     accuracy                           0.83       114
#    macro avg       0.84      0.80      0.81       114
# weighted avg       0.84      0.83      0.83       114
#
# Confusion matrix:
#  [[66  5]
#  [14 29]]
#
# Accuracy using sklearn: 78.07%
#
# The optimal number of nearest neighbors was 18
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.93      0.88        73
#          1.0       0.85      0.68      0.76        41
#
#     accuracy                           0.84       114
#    macro avg       0.84      0.81      0.82       114
# weighted avg       0.84      0.84      0.84       114
#
# Confusion matrix:
#  [[68  5]
#  [13 28]]
#
# Accuracy using sklearn: 78.95%
#
# The optimal number of nearest neighbors was 19
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.89      0.87        66
#          1.0       0.84      0.79      0.82        48
#
#     accuracy                           0.85       114
#    macro avg       0.85      0.84      0.85       114
# weighted avg       0.85      0.85      0.85       114
#
# Confusion matrix:
#  [[59  7]
#  [10 38]]
#
# Accuracy using sklearn: 80.70%
#
# The optimal number of nearest neighbors was 13
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.95      0.92        77
#          1.0       0.88      0.78      0.83        37
#
#     accuracy                           0.89       114
#    macro avg       0.89      0.87      0.88       114
# weighted avg       0.89      0.89      0.89       114
#
# Confusion matrix:
#  [[73  4]
#  [ 8 29]]
#
# Accuracy using sklearn: 82.46%
#
# The optimal number of nearest neighbors was 44
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.96      0.92        74
#          1.0       0.91      0.75      0.82        40
#
#     accuracy                           0.89       114
#    macro avg       0.89      0.85      0.87       114
# weighted avg       0.89      0.89      0.88       114
#
# Confusion matrix:
#  [[71  3]
#  [10 30]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.833333     0.842105     0.850877     0.894737
# Precision             0.838971     0.843996     0.849758     0.890011
# Recall                0.801998     0.807217     0.842803     0.865918
# F1 Score              0.813709     0.819937     0.845639     0.876311
# Optimal Neighbors    30.000000    18.000000    19.000000    13.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.885965       0.894737
# Precision             0.892817       0.892817
# Recall                0.854730       0.865918
# F1 Score              0.869023       0.876311
# Optimal Neighbors    44.000000      44.000000

# %% [markdown]
# # Maximum

# %%
# Maximum
evaluate(final_data3)
# Out:
# Accuracy using sklearn: 92.11%
#
# The optimal number of nearest neighbors was 1
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.97      0.96        68
#          1.0       0.95      0.91      0.93        46
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# Confusion matrix:
#  [[66  2]
#  [ 4 42]]
#
# Accuracy using sklearn: 93.86%
#
# The optimal number of nearest neighbors was 1
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.97      0.99        74
#          1.0       0.95      1.00      0.98        40
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.99      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[72  2]
#  [ 0 40]]
#
# Accuracy using sklearn: 94.74%
#
# The optimal number of nearest neighbors was 2
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98        67
#          1.0       1.00      0.94      0.97        47
#
#     accuracy                           0.97       114
#    macro avg       0.98      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion matrix:
#  [[67  0]
#  [ 3 44]]
#
# Accuracy using sklearn: 94.74%
#
# The optimal number of nearest neighbors was 16
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.97      0.98        75
#          1.0       0.95      0.97      0.96        39
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion matrix:
#  [[73  2]
#  [ 1 38]]
#
# Accuracy using sklearn: 93.86%
#
# The optimal number of nearest neighbors was 2
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96        68
#          1.0       1.00      0.89      0.94        46
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Confusion matrix:
#  [[68  0]
#  [ 5 41]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.947368     0.982456     0.973684     0.973684
# Precision             0.948701     0.976190     0.978571     0.968243
# Recall                0.941816     0.986486     0.968085     0.973846
# F1 Score              0.944928     0.980956     0.972568     0.970946
# Optimal Neighbors     1.000000     1.000000     2.000000    16.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.956140       0.982456
# Precision             0.965753       0.978571
# Recall                0.945652       0.986486
# F1 Score              0.953534       0.980956
# Optimal Neighbors     2.000000      16.000000

# %% [markdown]
# # Mean and Standard Error

# %%
# Mean and Standard Error
evaluate(final_data4)
# Out:
# Accuracy using sklearn: 91.23%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98        66
#          1.0       0.98      0.98      0.98        48
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[65  1]
#  [ 1 47]]
#
# Accuracy using sklearn: 92.98%
#
# The optimal number of nearest neighbors was 4
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98        71
#          1.0       0.98      0.95      0.96        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion matrix:
#  [[70  1]
#  [ 2 41]]
#
# Accuracy using sklearn: 91.23%
#
# The optimal number of nearest neighbors was 9
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98        69
#          1.0       0.98      0.96      0.97        45
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Confusion matrix:
#  [[68  1]
#  [ 2 43]]
#
# Accuracy using sklearn: 89.47%
#
# The optimal number of nearest neighbors was 13
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.98      0.95        63
#          1.0       0.98      0.88      0.93        51
#
#     accuracy                           0.94       114
#    macro avg       0.95      0.93      0.94       114
# weighted avg       0.94      0.94      0.94       114
#
# Confusion matrix:
#  [[62  1]
#  [ 6 45]]
#
# Accuracy using sklearn: 84.21%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.97      0.95        66
#          1.0       0.96      0.90      0.92        48
#
#     accuracy                           0.94       114
#    macro avg       0.94      0.93      0.94       114
# weighted avg       0.94      0.94      0.94       114
#
# Confusion matrix:
#  [[64  2]
#  [ 5 43]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.982456     0.973684     0.973684     0.938596
# Precision             0.982008     0.974206     0.974351     0.945013
# Recall                0.982008     0.969702     0.970531     0.933240
# F1 Score              0.982008     0.971863     0.972355     0.937200
# Optimal Neighbors     3.000000     4.000000     9.000000    13.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.938596       0.982456
# Precision             0.941546       0.982008
# Recall                0.932765       0.982008
# F1 Score              0.936440       0.982008
# Optimal Neighbors     3.000000      13.000000

# %% [markdown]
# # Standard Error and Maximum

# %%
# Standard Error and Maximum
evaluate(final_data5)
# Out:
# Accuracy using sklearn: 92.98%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.99      0.96        68
#          1.0       0.98      0.89      0.93        46
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# Confusion matrix:
#  [[67  1]
#  [ 5 41]]
#
# Accuracy using sklearn: 95.61%
#
# The optimal number of nearest neighbors was 7
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.99        77
#          1.0       1.00      0.95      0.97        37
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.97      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[77  0]
#  [ 2 35]]
#
# Accuracy using sklearn: 93.86%
#
# The optimal number of nearest neighbors was 1
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99        73
#          1.0       0.98      0.98      0.98        41
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[72  1]
#  [ 1 40]]
#
# Accuracy using sklearn: 94.74%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.99        76
#          1.0       1.00      0.95      0.97        38
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.97      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[76  0]
#  [ 2 36]]
#
# Accuracy using sklearn: 88.60%
#
# The optimal number of nearest neighbors was 1
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.97      0.95        71
#          1.0       0.95      0.86      0.90        43
#
#     accuracy                           0.93       114
#    macro avg       0.93      0.92      0.92       114
# weighted avg       0.93      0.93      0.93       114
#
# Confusion matrix:
#  [[69  2]
#  [ 6 37]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.947368     0.982456     0.982456     0.982456
# Precision             0.953373     0.987342     0.980956     0.987179
# Recall                0.938299     0.972973     0.980956     0.973684
# F1 Score              0.944481     0.979701     0.980956     0.979993
# Optimal Neighbors     3.000000     7.000000     1.000000     3.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.929825       0.982456
# Precision             0.934359       0.987342
# Recall                0.916148       0.980956
# F1 Score              0.923822       0.980956
# Optimal Neighbors     1.000000       7.000000

# %% [markdown]
# # Mean and Maximum

# %%
# Mean and Maximum
evaluate(final_data6)
# Out:
# Accuracy using sklearn: 96.49%
#
# The optimal number of nearest neighbors was 9
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        76
#          1.0       1.00      0.97      0.99        38
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# Confusion matrix:
#  [[76  0]
#  [ 1 37]]
#
# Accuracy using sklearn: 94.74%
#
# The optimal number of nearest neighbors was 8
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        71
#          1.0       1.00      0.98      0.99        43
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# Confusion matrix:
#  [[71  0]
#  [ 1 42]]
#
# Accuracy using sklearn: 99.12%
#
# The optimal number of nearest neighbors was 5
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        79
#          1.0       1.00      1.00      1.00        35
#
#     accuracy                           1.00       114
#    macro avg       1.00      1.00      1.00       114
# weighted avg       1.00      1.00      1.00       114
#
# Confusion matrix:
#  [[79  0]
#  [ 0 35]]
#
# Accuracy using sklearn: 92.98%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99        74
#          1.0       0.97      0.97      0.97        40
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[73  1]
#  [ 1 39]]
#
# Accuracy using sklearn: 92.98%
#
# The optimal number of nearest neighbors was 17
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.99        74
#          1.0       1.00      0.95      0.97        40
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.97      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[74  0]
#  [ 2 38]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.991228     0.991228          1.0     0.982456
# Precision             0.993506     0.993056          1.0     0.980743
# Recall                0.986842     0.988372          1.0     0.980743
# F1 Score              0.990065     0.990621          1.0     0.980743
# Optimal Neighbors     9.000000     8.000000          5.0     3.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.982456            1.0
# Precision             0.986842            1.0
# Recall                0.975000            1.0
# F1 Score              0.980513            1.0
# Optimal Neighbors    17.000000           17.0

# %% [markdown]
# # Mean, Standard Error and Maximum

# %%
# Mean, Standard Error and Maximum
evaluate(final_data7)
# Out:
# Accuracy using sklearn: 92.98%
#
# The optimal number of nearest neighbors was 4
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98        62
#          1.0       1.00      0.96      0.98        52
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[62  0]
#  [ 2 50]]
#
# Accuracy using sklearn: 92.11%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.99        70
#          1.0       1.00      0.95      0.98        44
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Confusion matrix:
#  [[70  0]
#  [ 2 42]]
#
# Accuracy using sklearn: 92.98%
#
# The optimal number of nearest neighbors was 15
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        68
#          1.0       1.00      0.98      0.99        46
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# Confusion matrix:
#  [[68  0]
#  [ 1 45]]
#
# Accuracy using sklearn: 91.23%
#
# The optimal number of nearest neighbors was 3
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        74
#          1.0       1.00      0.97      0.99        40
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# Confusion matrix:
#  [[74  0]
#  [ 1 39]]
#
# Accuracy using sklearn: 92.98%
#
# The optimal number of nearest neighbors was 5
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        80
#          1.0       1.00      0.88      0.94        34
#
#     accuracy                           0.96       114
#    macro avg       0.98      0.94      0.96       114
# weighted avg       0.97      0.96      0.96       114
#
# Confusion matrix:
#  [[80  0]
#  [ 4 30]]
#                    Validation1  Validation2  Validation3  Validation4  \
# Accuracy              0.982456     0.982456     0.991228     0.991228
# Precision             0.984375     0.986111     0.992754     0.993333
# Recall                0.980769     0.977273     0.989130     0.987500
# F1 Score              0.982260     0.981330     0.990856     0.990315
# Optimal Neighbors     4.000000     3.000000    15.000000     3.000000
#
#                    Validation5  Maximum Value
# Accuracy              0.964912       0.991228
# Precision             0.976190       0.993333
# Recall                0.941176       0.989130
# F1 Score              0.956555       0.990856
# Optimal Neighbors     5.000000      15.000000

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_axes([0,0,1,1])
plt.rcParams["font.family"] = "Times New Roman"

feature_comb = ['Mean', 'SE', 'Max', 'Mean\n& SE', 'Max\n& SE', 'Mean\n& Max', 'Mean, Max\n & SE']

accuracy = [0.964912, 0.877193, 0.991228, 0.973684, 0.982456, 0.991228, 0.991228]
ax.bar(feature_comb,accuracy)
ax.set_xlabel('Feature Combinations', fontsize = 20)
ax.set_ylabel('Accuracy', fontsize = 20)
ax.set_title('Comparison of Accuracy Using Different Feature \nCombinations using K-NN (With Normalization)', fontsize = 22)

for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

plt.ylim([0.875, 1])
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(8,5))
ax = fig.add_axes([0,0,1,1])
plt.rcParams["font.family"] = "Times New Roman"

feature_comb = ['Mean', 'SE', 'Max', 'Mean\n& SE', 'Max\n& SE', 'Mean\n& Max', 'Mean, Max\n & SE']

accuracy = [0.962660, 0.855696, 0.990856, 0.972120, 0.980263, 0.990195, 0.990195]
ax.bar(feature_comb,accuracy)
ax.set_xlabel('Feature Combinations', fontsize = 20)
ax.set_ylabel('F1', fontsize = 20)
ax.set_title('Comparison of F1 Score Using Different Feature \nCombinations using K-NN (With Normalization)', fontsize = 22)

for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

plt.ylim([0.875, 1])
plt.tight_layout()
plt.show()
